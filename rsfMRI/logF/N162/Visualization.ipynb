# %%
from nilearn import plotting
from nilearn import image
import matplotlib.pyplot as plt
# Out:
# /home/andrea/.local/lib/python3.7/site-packages/nilearn/datasets/__init__.py:90: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
oldfont = plt.rcParams['font.sans-serif']
plt.rcParams['font.sans-serif'] = ['FreeSans']

tmap = image.load_img("spmT_0001.nii")
tmap = image.math_img("np.where(i<0,0,i)",i=tmap)

fig, ax = plt.subplots(1, 1, figsize=(8,3))
d=plotting.plot_stat_map(tmap, 
                       threshold=5.212,  # FWE < 0.05
                         axes=ax, 
                       cut_coords=(0, -21, 10))
plt.suptitle("Voxels showing significant effects of LFOs at $p$ < .05 FWE ($T$ > 5.21)")
plt.tight_layout()
plt.savefig("logF.png")
# Out:
# /home/andrea/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   del sys.path[0]
