# %%
import nilearn
import matplotlib
from nilearn import plotting
from nilearn import datasets
from nilearn import surface
from nilearn import image
import nilearn.plotting as nip
import nilearn.image as nii
import matplotlib.pyplot as plt
from matplotlib.colors import to_rgba
import matplotlib.pyplot as plt
import string

fs = datasets.fetch_surf_fsaverage5()
#fs = datasets.fetch_surf_nki_enhanced()


tasks = ["Emotion", "Social", "Relational", "WM", "Language", "Gambling"]
task_names = {"Emotion" : "Emotion Processing",
              "Social" : "Social Cognition",
              "Relational" : "Relational Reasoning",
              "WM" : "Working Memory",
              "Language" : "Language & Math",
              "Gambling" : "Incentive Processing"}

cols = [list(to_rgba(x)) for x in \
        ["#cc00cc", "#ff9900", "#ff3333", "#00cc33", "#00ccff"]]

VOIS = ['Action', 'LTM', 'Perception', 'Procedural', 'WM']


#statmap = plt.get_cmap("PuOr")
#statmap = plt.get_cmap("Spectral")
statmap = plt.get_cmap("hot_white_bone")


def load_vois(task):
    f = open("%s/vois.txt" % task)
    vois = {}
    for line in f.readlines():
        name, coords = line.split()[:2]
        xyz = [int(x) for x in coords.split(",")]
        vois[name] = xyz
    
    return vois


def load_individual_coords(task):
    vdict = {}
    for voi in VOIS:
    
        # Opens file and extract MNI coordinates
        # ----------------------------------------------------------
        
        f = open("%s/%s_xyz.txt" % (task, voi), "r")
        tokens = [line.split() for line in f.readlines()[1:]]
        coords = [x[2:5] for x in tokens]
        mni = [[float(y) for y in x] for x in coords]
        name = tokens[0][1]
        vdict[name] = mni

    return vdict
# Out:
# /tmp/ipykernel_141506/2086757791.py:14: VisibleDeprecationWarning: fetch_surf_fsaverage5 has been deprecated and will be removed in a future release. Use fetch_surf_fsaverage(mesh='fsaverage5')
#   fs = datasets.fetch_surf_fsaverage5()

# %%
fig = plt.figure(figsize=(6,10))


for i, d in enumerate(sorted(tasks)):
    print("loading: " + d)
    ax = plt.subplot(3, 2, (i+1))
    #img = image.threshold_img(d+"/spmT_0001.nii", threshold=7.0)
    #img = image.threshold_img(d+"/spmT_0001.nii",)
    img = image.load_img(d+"/spmT_0001.nii")
    data = img.get_fdata()
    data[data < 0] = 0.0  # Remove negative values
    img = image.smooth_img(img, fwhm=4)

    gb = plotting.plot_glass_brain(img, display_mode="l",
                                   axes=ax, vmax=30, vmin=0,
                                   title="%s" % d, colorbar = False, #(i == 1),
                                   cmap=statmap)

    #print(load_vois(d))
    vois = load_vois(d)
    print(vois)

    # Order them
    coords = [vois[name] for name in VOIS]

    gb.add_markers(coords,
                   marker_color = cols,
                   marker_size = 60,
                   marker = "o")

    
plt.savefig("uberfigure.png")

fig = plt.figure(figsize=(24, 18))


for i, d in enumerate(sorted(tasks)):
    print("loading: " + d)
    ax = plt.subplot(3, 4, (2*i+1))
    #img = image.threshold_img(d+"/spmT_0001.nii", threshold=7.0)
    #img = image.threshold_img(d+"/spmT_0001.nii",)
    img = image.load_img(d+"/spmT_0001.nii")
    data = img.get_fdata()
    data[data < 0] = 0.0  # Remove negative values
    img = image.smooth_img(img, fwhm=4)
        

    # Task-Related activity
    
    gb = plotting.plot_glass_brain(img, display_mode="l",
                                   axes=ax, vmin=0, vmax=30,
                                   title="%s" % d, colorbar = False, #(i == 1),
                                   cmap=statmap)

    #print(load_vois(d))
    vois = load_vois(d)
    #print(vois)

    # Order them
    coords = [vois[name] for name in VOIS]

    gb.add_markers(coords,
                   marker_color = cols,
                   marker_size = 120,
                   marker = "o")


    # Individual locations

    ax = plt.subplot(3, 4, (2*i+2))
    
    gb = plotting.plot_glass_brain(img,
                                   display_mode="l",
                                   axes=ax, cmap=statmap,
                                   title="%s" % d, colorbar = False, #(i == 1),
                                   )

    coords = load_individual_coords(d)
    for ii, voi in enumerate(VOIS):
        gb.add_markers(coords[voi], marker_color=cols[ii],
                       marker="+", marker_size=5)
    
plt.savefig("uberfigure2.png")


fig = plt.figure(figsize=(8, 8))


for i, d in enumerate(sorted(tasks)):
    print("loading: " + d)
    # ax = plt.subplot(2, 3, (i+1))
    img = image.load_img(d + "/spmT_0001.nii")
    data = img.get_fdata()
    data[data < 0] = 0.0  # Remove negative values
    img = image.smooth_img(img, fwhm=4)
        

     # Individual locations

    ax = plt.subplot(2, 3, (i+1))
    gb = plotting.plot_glass_brain(img, vmin=0.0,
                                   display_mode="l",
                                   axes=ax, cmap=statmap,
                                   colorbar = True, #(i == 1),
                                   )
    coords = load_individual_coords(d)
    N = [len(x) for x in coords.values()][0]

    for ii, voi in enumerate(VOIS):
        gb.add_markers(coords[voi], marker_color=cols[ii],
                       marker="+", marker_size=40)

    font = {'fontname' : 'FreeSans',
            'fontweight' : 'bold',
            'fontsize' : 20}

    #ax.set_title("(%s) %s\n" % (string.ascii_uppercase[i], task_names[d]) 
    #             + r"$N = %d$" % (N), **font)

    ax.set_title("(%s) %s\nN = %d" % (string.ascii_uppercase[i], task_names[d], N),
                 **font)
    
    #plt.rcParams['font.family']=['FreeSans']
# Out:
# loading: Emotion
# {'Procedural': [-24, -4, 8], 'WM': [-40, 6, 30], 'LTM': [-56, -18, 6], 'Perception': [-34, -80, -12], 'Action': [-38, -26, 50]}
# loading: Gambling
# {'Procedural': [-18, 6, 14], 'WM': [-46, 2, 34], 'LTM': [-38, -6, -8], 'Perception': [-40, -80, -4], 'Action': [-40, -22, 56]}
# loading: Language
# {'Procedural': [-22, 10, 2], 'WM': [-46, 2, 30], 'LTM': [-50, -10, -22], 'Perception': [-52, -22, 4], 'Action': [-38, -26, 50]}
# loading: Relational
# {'Procedural': [-16, 2, 18], 'WM': [-44, 16, 44], 'LTM': [-48, -56, -14], 'Perception': [-12, -92, -2], 'Action': [-38, -22, 56]}
# loading: Social
# {'Procedural': [-14, 12, 6], 'WM': [-52, 6, 32], 'LTM': [-54, 0, -14], 'Perception': [-38, -84, -4], 'Action': [-40, -18, 52]}
# loading: WM
# {'Action': [-38, -22, 56], 'Perception': [-34, -50, -18], 'WM': [-48, 22, 36], 'Procedural': [-14, 10, 10], 'LTM': [-60, -36, -8]}
# loading: Emotion
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: Gambling
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: Language
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: Relational
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: Social
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: WM
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: Emotion
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: Gambling
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: Language
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: Relational
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: Social
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# loading: WM
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## Figure for Granger Paper
#
# Figure for the TopiCS paper on Granger causality.

# %%
from matplotlib.lines import Line2D

voiscolors = ["purple", "orange", "red", "green", "aqua"]
vois = ["Action", "LTM", "Perception", "Procedural", "WM"]
taskcolors = ["#00798c", "#d1495b", "#edae49", "#66a182", "#2e4057", "#8d96a3"]

tasks = ["Emotion", "Gambling", "Language", "Relational", "Social", "WM"]

task_names = dict(zip(tasks, ["Emotion Processing", "Incentive Processing", "Language and Math", "Relational Reasoning", "Social Cognition", "Working Memory"]))

timages = []

for task in tasks:
    img = nii.load_img("%s/spmT_0001.nii" % (task,))
    data = img.get_fdata()
    data[data < 0] = 0.0  # Remove negative values
    img = image.smooth_img(img, fwhm=4)
    timages.append(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_141506/2838881197.py in <module>
#      47 axs[6].set_axis_off()
#      48 handles = [Line2D([0], [0], marker='o', markerfacecolor=x, color=x, markersize=6) for x in voiscolors]
# ---> 49 axs.flat[v_i].legend(handles, tasks, loc="center", ncol=3)
#      50
#      51
#
# AttributeError: 'dict' object has no attribute 'flat'

# %%
fig, axs = plt.subplots(4, 2, figsize=(12, 8))

#gs_kw = dict(width_ratios=[1, 1], height_ratios=[2, 2, 2, 1])
#fig, axs = plt.subplot_mosaic([[0, 1],
#                               [2, 3],
#                               [4, 5],
#                               [6, 6]],
#                              gridspec_kw=gs_kw, figsize=(10, 6),
#                              constrained_layout=True)

v_i = 0

for task in tasks:
    d=nip.plot_glass_brain(None, #"%s/spmT_0001.nii" % (task,), #timages[v_i], 
                           vmin=0.0,
                           axes=axs.flat[v_i],
                           colorbar=True)
    d.add_contours(timages[v_i], levels=[15], colors="grey", filled=True, alpha=0.75)
    coords = load_individual_coords(task)
    for ii, voi in enumerate(vois):
        d.add_markers(coords[voi], marker_color=[cols[ii]]*len(coords[voi]),
                       marker=".", marker_size=2)
    axs.flat[v_i].set_title(task_names[task], fontname="FreeSans")
    v_i = v_i + 1

axs.flat[v_i].set_axis_off()
handles = [Line2D([0], [0], marker='o', markerfacecolor=x, color='white', markersize=10) for x in voiscolors]
axs.flat[v_i].legend(handles, vois, loc="upper center", ncol=3, prop={'family':"FreeSans"})

axs.flat[v_i + 1].set_axis_off()

# Title
fig.suptitle("Individual ROI Centroids", fontname="FreeSans", fontweight="bold")
#fig.tight_layout()

# Save and visualize
plt.savefig("rois_figure.png", dpi=300)
plt.show()
